# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
real_data = pd.read_csv('data/breach_report.csv')
synthetic_data = pd.read_csv('synthetic_data.csv')

# Streamlit app header
st.title("Real vs Synthetic Data Comparison")

# Sidebar for navigation
st.sidebar.title("Navigation")
app_mode = st.sidebar.selectbox("Choose a page", ["Home", "Data Comparison", "Synthetic Data"])

# Home page
if app_mode == "Home":
    st.markdown("""
    ## Welcome to the Real vs Synthetic Data Comparison App
    This app allows you to compare real and synthetic breach report data.
    You can explore statistical comparisons, visualizations, and more.
    """)

# Data Comparison page
elif app_mode == "Data Comparison":
    st.markdown("""
    ## Real vs Synthetic Data
    Below, you can compare the statistical summaries and visualizations for both datasets.
    """)

    # Display data summary
    st.subheader("Real Data Summary:")
    st.write(real_data.describe())

    st.subheader("Synthetic Data Summary:")
    st.write(synthetic_data.describe())

    # Plot comparison for a specific column (e.g., 'individuals_affected')
    st.subheader('Distribution Comparison (individuals_affected)')
    fig, ax = plt.subplots(figsize=(10, 6))
    sns.histplot(real_data['individuals_affected'], color='blue', kde=True, label='Real Data', ax=ax)
    sns.histplot(synthetic_data['individuals_affected'], color='red', kde=True, label='Synthetic Data', ax=ax)
    ax.legend()
    st.pyplot(fig)

# Synthetic Data page
elif app_mode == "Synthetic Data":
    st.markdown("""
    ## Synthetic Data
    Below is the synthetic data generated.
    """)

    # Display synthetic data
    st.dataframe(synthetic_data)
# Out:
# 2025-04-01 00:46:09.127 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-01 00:46:09.243
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-04-01 00:46:09.244 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-01 00:46:09.244 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-01 00:46:09.244 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-01 00:46:09.245 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-01 00:46:09.245 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-01 00:46:09.245 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-01 00:46:09.246 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-01 00:46:09.246 Session state does not function when running a script without `streamlit run`
# 2025-04-01 00:46:09.247 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-01 00:46:09.247 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-01 00:46:09.248 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-01 00:46:09.248 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# !pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.44.0-py3-none-any.whl.metadata (8.9 kB)
# Collecting altair<6,>=4.0 (from streamlit)
#   Downloading altair-5.5.0-py3-none-any.whl.metadata (11 kB)
# Collecting blinker<2,>=1.0.0 (from streamlit)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<6,>=4.0 (from streamlit)
#   Downloading cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting click<9,>=7.0 (from streamlit)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: numpy<3,>=1.23 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from streamlit) (2.0.2)
# Requirement already satisfied: packaging<25,>=20 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from streamlit) (11.1.0)
# Collecting protobuf<6,>=3.20 (from streamlit)
#   Downloading protobuf-5.29.4-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting pyarrow>=7.0 (from streamlit)
#   Downloading pyarrow-19.0.1-cp39-cp39-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: requests<3,>=2.27 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from streamlit) (2.32.3)
# Collecting tenacity<10,>=8.1.0 (from streamlit)
#   Downloading tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from streamlit) (4.12.2)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl.metadata (44 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from streamlit) (6.4.2)
# Requirement already satisfied: jinja2 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from altair<6,>=4.0->streamlit) (1.33.0)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from pandas<3,>=1.4.0->streamlit) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit) (2025.1.31)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.22.3)
# Requirement already satisfied: six>=1.5 in /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Downloading streamlit-1.44.0-py3-none-any.whl (9.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 16.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading altair-5.5.0-py3-none-any.whl (731 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.2/731.2 kB 10.1 MB/s eta 0:00:00
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
# Downloading GitPython-3.1.44-py3-none-any.whl (207 kB)
# Downloading protobuf-5.29.4-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
# Downloading pyarrow-19.0.1-cp39-cp39-manylinux_2_28_x86_64.whl (42.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 MB 13.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 8.7 MB/s eta 0:00:00 MB/s eta 0:00:010:01
# Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl (79 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Installing collected packages: watchdog, toml, tenacity, smmap, pyarrow, protobuf, click, cachetools, blinker, pydeck, gitdb, gitpython, altair, streamlit
# Successfully installed altair-5.5.0 blinker-1.9.0 cachetools-5.5.2 click-8.1.8 gitdb-4.0.12 gitpython-3.1.44 protobuf-5.29.4 pyarrow-19.0.1 pydeck-0.9.1 smmap-5.0.2 streamlit-1.44.0 tenacity-9.0.0 toml-0.10.2 watchdog-6.0.0

# %%
streamlit run /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages/ipykernel_launcher.py [
# Out:
#   Cell In[4], line 1
#     streamlit run /home/pradyumnakubear/anaconda3/envs/first_python_env/lib/python3.9/site-packages/ipykernel_launcher.py [
#               ^
# SyntaxError: invalid syntax
